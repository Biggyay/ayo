# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\crime_data_chicago.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date  \
# 0           0   6407111    HP485721  07/26/2008 02:30:00 PM
# 1           1  11398199    JB372830  07/31/2018 10:57:00 AM
# 2           2   5488785    HN308568  04/27/2007 10:30:00 AM
# 3           3  11389116    JB361368  07/23/2018 08:55:00 AM
# 4           4  12420431    JE297624  07/11/2021 06:40:00 AM
#
#                   Block  IUCR       Primary Type               Description  \
# 0  085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE                TO VEHICLE
# 1     092XX S ELLIS AVE  143C  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 2     062XX N TRIPP AVE  0610           BURGLARY            FORCIBLE ENTRY
# 3    0000X N KEELER AVE  0560            ASSAULT                    SIMPLE
# 4   016XX W HARRISON ST  051A            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  ...  Ward  Community Area  \
# ...

# %%
df.shape
# Out:
# (2278726, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278726 entries, 0 to 2278725
# Data columns (total 23 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   ID                    int64
#  2   Case Number           object
#  3   Date                  object
#  4   Block                 object
#  5   IUCR                  object
#  6   Primary Type          object
#  7   Description           object
#  8   Location Description  object
#  9   Arrest                bool
#  10  Domestic              bool
#  11  Beat                  int64
#  12  District              float64
#  13  Ward                  float64
#  14  Community Area        float64
#  15  FBI Code              object
#  16  X Coordinate          float64
#  17  Y Coordinate          float64
#  18  Year                  int64
#  19  Updated On            object
#  20  Latitude              float64
#  21  Longitude             float64
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0   6407111    HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 1  11398199    JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 2   5488785    HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 3  11389116    JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
# 4  12420431    JE297624  07/11/2021 06:40:00 AM   016XX W HARRISON ST  051A
#
#         Primary Type               Description  \
# 0    CRIMINAL DAMAGE                TO VEHICLE
# 1  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 2           BURGLARY            FORCIBLE ENTRY
# 3            ASSAULT                    SIMPLE
# 4            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# 0                                  STREET   False     False  ...  10.0
# 1                               POOL ROOM    True     False  ...   8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278726 entries, 0 to 2278725
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
missing = df.isna()

# %%
missing = df.isna().sum()

# %%
missing
# Out:
# ID                           0
# Case Number                  1
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      2877
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    12
# Ward                    184695
# Community Area          184267
# FBI Code                     0
# X Coordinate             23985
# Y Coordinate             23985
# Year                         0
# Updated On                   0
# Latitude                 23985
# Longitude                23985
# Location                 23985
# dtype: int64

# %%
df.drop(columns=['Case Number', 'IUCR'])
# Out:
#                ID                    Date                 Block  \
# 0         6407111  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE
# 1        11398199  07/31/2018 10:57:00 AM     092XX S ELLIS AVE
# 2         5488785  04/27/2007 10:30:00 AM     062XX N TRIPP AVE
# 3        11389116  07/23/2018 08:55:00 AM    0000X N KEELER AVE
# 4        12420431  07/11/2021 06:40:00 AM   016XX W HARRISON ST
# ...           ...                     ...                   ...
# 2278721  10716043  10/14/2016 02:35:00 PM      006XX N CLARK ST
# 2278722   1740109  09/11/2001 10:20:00 PM       052XX W LAKE ST
# 2278723   4737434  05/10/2006 07:49:00 PM  007XX E OAKWOOD BLVD
# 2278724  11122832  10/18/2017 10:30:00 PM       002XX W ERIE ST
# 2278725   3409804  06/09/2004 08:19:28 PM   016XX N ROCKWELL ST
#
#               Primary Type                   Description  \
# 0          CRIMINAL DAMAGE                    TO VEHICLE
# 1        WEAPONS VIOLATION      UNLAWFUL POSS AMMUNITION
# ...

# %%
df.drop(columns=['ID'])
# Out:
#         Case Number                    Date                 Block  IUCR  \
# 0          HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 1          JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 2          HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 3          JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
# 4          JE297624  07/11/2021 06:40:00 AM   016XX W HARRISON ST  051A
# ...             ...                     ...                   ...   ...
# 2278721    HZ474139  10/14/2016 02:35:00 PM      006XX N CLARK ST  0560
# 2278722     G546340  09/11/2001 10:20:00 PM       052XX W LAKE ST  0460
# 2278723    HM342705  05/10/2006 07:49:00 PM  007XX E OAKWOOD BLVD  0560
# 2278724    JA476827  10/18/2017 10:30:00 PM       002XX W ERIE ST  1360
# 2278725    HK420105  06/09/2004 08:19:28 PM   016XX N ROCKWELL ST  1811
#
#               Primary Type                   Description  \
# ...

# %%
df.Ward.head()
# Out:
# 0    10.0
# 1     8.0
# 2    39.0
# 3    28.0
# 4    27.0
# Name: Ward, dtype: float64

# %%
df.Ward.unique()
# Out:
# array([10.,  8., 39., 28., 27., nan, 29., 37., 26., 35., 14.,  1., 17.,
#         3., 44., 36.,  4.,  2.,  6.,  7., 40., 42., 20., 13., 11., 34.,
#        47., 33.,  9., 21., 45., 25., 24., 15., 16., 19., 43., 30., 23.,
#        32., 31., 22., 50., 49.,  5., 46., 12., 41., 38., 18., 48.])

# %%
ward_miss = df.Ward.mode()[0] #replacement of ward missing data with mode
df1 = df.fillna(ward_miss, inplace=True) # filling it the na values

# %%
df['Ward'].head()
# Out:
# 0    10.0
# 1     8.0
# 2    39.0
# 3    28.0
# 4    27.0
# Name: Ward, dtype: float64

# %%
df.Ward.unique()
# Out:
# array([10.,  8., 39., 28., 27., 29., 37., 26., 35., 14.,  1., 17.,  3.,
#        44., 36.,  4.,  2.,  6.,  7., 40., 42., 20., 13., 11., 34., 47.,
#        33.,  9., 21., 45., 25., 24., 15., 16., 19., 43., 30., 23., 32.,
#        31., 22., 50., 49.,  5., 46., 12., 41., 38., 18., 48.])

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0   6407111    HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 1  11398199    JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 2   5488785    HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 3  11389116    JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
# 4  12420431    JE297624  07/11/2021 06:40:00 AM   016XX W HARRISON ST  051A
#
#         Primary Type               Description  \
# 0    CRIMINAL DAMAGE                TO VEHICLE
# 1  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 2           BURGLARY            FORCIBLE ENTRY
# 3            ASSAULT                    SIMPLE
# 4            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# 0                                  STREET   False     False  ...  10.0
# 1                               POOL ROOM    True     False  ...   8.0
# ...

# %%
df['Community Area'].unique()
# Out:
# array([46., 47., 12., 26., 28., 25., 23., 22., 27., 63., 24., 71., 38.,
#         6., 19., 55., 36., 32., 69., 43.,  4.,  8., 42., 65., 60., 14.,
#        49., 35., 40., 21., 73., 52., 15., 18., 16., 61., 66., 44., 45.,
#        67., 74.,  2., 29., 51., 57., 17.,  7., 62., 30., 31., 13., 75.,
#         5.,  1., 39., 53.,  3., 68., 11., 37., 41., 48., 33., 59., 58.,
#        76., 54., 10., 20., 34., 77., 64., 56., 70.,  9., 72., 50.,  0.])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from datetime import datetime

def extract_and_map_month(date):
    
    date_column = pd.to_datetime(date, format='%m/%d/%Y %I:%M:%S %p')

    month_names = date_column.dt.month_name()

    return month_names

# %%
df['Month'] = extract_and_map_month(df['Date'])

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0   6407111    HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 1  11398199    JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 2   5488785    HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 3  11389116    JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
# 4  12420431    JE297624  07/11/2021 06:40:00 AM   016XX W HARRISON ST  051A
#
#         Primary Type               Description  \
# 0    CRIMINAL DAMAGE                TO VEHICLE
# 1  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 2           BURGLARY            FORCIBLE ENTRY
# 3            ASSAULT                    SIMPLE
# 4            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  Domestic  ...  \
# 0                                  STREET   False     False  ...
# 1                               POOL ROOM    True     False  ...
# ...

# %%
df.groupby('Month')['Primary Type'].value_counts()
# Out:
# Month      Primary Type
# April      THEFT                       37305
#            BATTERY                     35676
#            CRIMINAL DAMAGE             22501
#            NARCOTICS                   18878
#            ASSAULT                     12687
#                                        ...
# September  HUMAN TRAFFICKING               5
#            PUBLIC INDECENCY                5
#            OTHER NARCOTIC VIOLATION        3
#            NON - CRIMINAL                  2
#            RITUALISM                       2
# Name: Primary Type, Length: 399, dtype: int64

# %%
df.describe().round(2)
# Out:
#                 ID        Beat    District        Ward  Community Area  \
# count   2278726.00  2278726.00  2278726.00  2278726.00      2278726.00
# mean    6882067.87     1186.44       11.29       23.15           36.75
# std     3419167.96      702.68        6.95       13.34           20.81
# min         637.00      111.00        1.00        1.00            0.00
# 25%     3716076.25      621.00        6.00       11.00           24.00
# 50%     6885990.00     1034.00       10.00       24.00           29.00
# 75%     9887567.75     1731.00       17.00       32.00           53.00
# max    12781989.00     2535.00       31.00       50.00           77.00
#
#        X Coordinate  Y Coordinate        Year    Latitude   Longitude
# count    2278726.00    2278726.00  2278726.00  2278726.00  2278726.00
# mean     1152311.53    1865899.11     2009.64       41.70      -86.45
# std       120005.84     195074.28        6.02        1.42       11.80
# ...

# %%
df.drop(columns=['ID'], inplace=True)

# %%
df1 = ['Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area']
df[df1].describe().round(2)
# Out:
#              Beat    District        Ward  Community Area
# count  2278726.00  2278726.00  2278726.00      2278726.00
# mean      1186.44       11.29       23.15           36.75
# std        702.68        6.95       13.34           20.81
# min        111.00        1.00        1.00            0.00
# 25%        621.00        6.00       11.00           24.00
# 50%       1034.00       10.00       24.00           29.00
# 75%       1731.00       17.00       32.00           53.00
# max       2535.00       31.00       50.00           77.00

# %%
df[df1].skew().round(3)
# Out:
# Arrest            1.066
# Domestic          2.105
# Beat              0.389
# District          0.436
# Ward              0.085
# Community Area    0.287
# dtype: float64

# %%
df[df1].kurtosis().round(3)
# Out:
# Arrest           -0.864
# Domestic          2.430
# Beat             -0.957
# District         -0.860
# Ward             -0.949
# Community Area   -0.963
# dtype: float64

# %%
# Univariate Analysis: Graphical
# histogram
hists = ['Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area'] # create a list of numerical features
df[hists].hist(figsize=(10,10));

# %%
df[hists].plot(kind='density', subplots=True, layout=(3, 2), sharex=False, figsize=(10, 10));

# %%
sns.boxplot(x='Ward', data=df);

# %%
# Multivariate analysis
# Correlation between time of day and type of crime
hourly_crime = df.groupby(df['Date'].dt.hour)['Primary Type'].value_counts()
print(hourly_crime)

# %%
df['Primary Type'].value_counts().head() # mist common crime

# %%
df.groupby('Year').size() # trend in crimes

# %%
df['Location Description'].value_counts().head()

# %%
df.groupby('Primary Type')['Arrest'].mean().sort_values(ascending=False)
# arrest rate for different crimes

# %%
# Correlation between numerical variables
# Select numerical columns
num_cols = ['Community Area', 'X Coordinate', 'Y Coordinate', 'Latitude', 'Longitude']

# Compute correlation matrix
corr_matrix = df[num_cols].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
# Correlation between crime types and location:
location_crime_cross = pd.crosstab(df['Crime Type'], df['Location'])

# Plotting heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(location_crime_cross, cmap='coolwarm', annot=True, fmt='d')
plt.title('Cross-tabulation of Crime Type and Location')
plt.xlabel('Location')
plt.ylabel('Crime Type')
plt.show()

# %%
# Correlation between crime rate and temporal factors:
# Selecting relevant columns
temporal_cols = ['Crime Rate', 'Time of Day', 'Day of Week', 'Month']

# Compute correlation matrix
temporal_corr = df[temporal_cols].corr()

# Plotting heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(temporal_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Crime Rate and Temporal Factors')
plt.show()

# %%
# Correlation between crime rate and law enforcement activity:
# Box plot for Crime Rate and Law Enforcement Activity
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Crime Rate', 'Arrests']])
plt.title('Box Plot of Crime Rate and Law Enforcement Activity')
plt.xticks(rotation=45)
plt.show()

# %%
df.corr

# %%
# using heatmap for correlation between variables
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
